# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/patilgaurav/ThinkStats2/blob/master/WNS.ipynb)

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-596c9605-6e90-48a9-8b9a-b73f7e2db726" name="files[]" multiple disabled />
#      <output id="result-596c9605-6e90-48a9-8b9a-b73f7e2db726">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving train.csv to train.csv
# User uploaded file "train.csv" with length 3759647 bytes

# %%
import io
df = pd.read_csv(io.StringIO(uploaded['train.csv'].decode('utf-8')))
df

# %%
df = df.fillna(df.mean())

# %%
df['education'].value_counts(normalize=False).loc["Bachelor's"]
# Out:
# 39078

# %%
df[['education']] = df[['education']].fillna(value="Bachelor's")

# %%
df
# Out:
#        employee_id         department     region         education gender  \
# 0            65438  Sales & Marketing   region_7  Master's & above      f
# 1            65141         Operations  region_22        Bachelor's      m
# 2             7513  Sales & Marketing  region_19        Bachelor's      m
# 3             2542  Sales & Marketing  region_23        Bachelor's      m
# 4            48945         Technology  region_26        Bachelor's      m
# 5            58896          Analytics   region_2        Bachelor's      m
# 6            20379         Operations  region_20        Bachelor's      f
# 7            16290         Operations  region_34  Master's & above      m
# 8            73202          Analytics  region_20        Bachelor's      m
# 9            28911  Sales & Marketing   region_1  Master's & above      m
# 10           29934         Technology  region_23        Bachelor's      m
# 11           49017  Sales & Marketing   region_7        Bachelor's      f
# ...

# %%
df.drop(['employee_id'], axis=1, inplace=True)
